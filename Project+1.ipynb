# %% [markdown]
# # First Solution

# %%
import time
import requests

# %%
#import urllib.request
#x = urllib.request.urlopen('http://www.city-data.com/indexes/neighborhoods/IA/1/')
#print(x.read())

#LIST OF ALL URLS
#urls = ['http://www.city-data.com/indexes/neighborhoods/IA/1', 'http://www.city-data.com/indexes/neighborhoods/IA/2',
#       'http://www.city-data.com/indexes/neighborhoods/IA/3', 'http://www.city-data.com/indexes/neighborhoods/IA/4',
#       'http://www.city-data.com/indexes/neighborhoods/IA/5', 'http://www.city-data.com/indexes/neighborhoods/IA/6',
#       'http://www.city-data.com/indexes/neighborhoods/IA/7', 'http://www.city-data.com/indexes/neighborhoods/IA/8',
#       'http://www.city-data.com/indexes/neighborhoods/IA/9', 'http://www.city-data.com/indexes/neighborhoods/IA/10',
#       'http://www.city-data.com/indexes/neighborhoods/IA/11,' 'http://www.city-data.com/indexes/neighborhoods/IA/12',
#       'http://www.city-data.com/indexes/neighborhoods/IA/13']

#p = requests.get(url)
#b = BeautifulSoup(p.content, "html.parser")

from urllib import urlopen
from bs4 import BeautifulSoup

import re

url = 'http://www.city-data.com/indexes/neighborhoods/IA/1'
#POSSIBLE NEXT STEP
#url[0]
#for url in urls:
    #url = "http://www.city-data.com/indexes/neighborhoods/IA/1/"
    #url[url+1]
html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : from urllib import urlopen
"neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])
#return
#assuming you can access the site, this should successfully scrape the titles and urls for each Des Moines city from each page
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-37fb444581c8> in <module>()
#      15 #b = BeautifulSoup(p.content, "html.parser")
#      16
# ---> 17 from urllib import urlopen
#      18 from bs4 import BeautifulSoup
#      19
#
# ImportError: cannot import name 'urlopen'

# %% [markdown]
# # Second Solution (either should work)

# %%
import time
import requests

import urllib.request
x = urllib.request.urlopen('http://www.city-data.com/indexes/neighborhoods/IA/1/')
print(x.read())

#LIST OF ALL URLS
#urls = ['http://www.city-data.com/indexes/neighborhoods/IA/1', 'http://www.city-data.com/indexes/neighborhoods/IA/2',
#       'http://www.city-data.com/indexes/neighborhoods/IA/3', 'http://www.city-data.com/indexes/neighborhoods/IA/4',
#       'http://www.city-data.com/indexes/neighborhoods/IA/5', 'http://www.city-data.com/indexes/neighborhoods/IA/6',
#       'http://www.city-data.com/indexes/neighborhoods/IA/7', 'http://www.city-data.com/indexes/neighborhoods/IA/8',
#       'http://www.city-data.com/indexes/neighborhoods/IA/9', 'http://www.city-data.com/indexes/neighborhoods/IA/10',
#       'http://www.city-data.com/indexes/neighborhoods/IA/11,' 'http://www.city-data.com/indexes/neighborhoods/IA/12',
#       'http://www.city-data.com/indexes/neighborhoods/IA/13']

p = requests.get(url)
b = BeautifulSoup(p.content, "html.parser")

#from urllib import urlopen
#from bs4 import BeautifulSoup

#import re

url = 'http://www.city-data.com/indexes/neighborhoods/IA/1'
#POSSIBLE NEXT STEP
#url[0]
#for url in urls:
    #url = "http://www.city-data.com/indexes/neighborhoods/IA/1/"
    #url[url+1]
html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : "neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])
#return
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n \n   <meta charset="utf-8"/>\n<meta http-equiv="Content-Language" content="en"/>\n<meta http-equiv="X-UA-Compatible" content="IE=7, IE=9,IE=edge"/>\n<meta name="robots" content="index, follow"/>\n<meta name="robots" content="all"/>\n<meta name="googlebot" content="all"/>\n<meta name="msnbot" msnbot="all"/>\n<meta name="apple-mobile-web-app-capable" content="YES"/>\n<meta name="viewport" content="width=device-width, initial-scale=1"/>\n\n<!-- Quantcast Tag, part 1 -->\n<script type="text/javascript">\n  var _qevents = _qevents || [];\n  (function() {\n  var elem = document.createElement(\'script\');\n  elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge")\n  + ".quantserve.com/quant.js";\n  elem.async = true;\n  elem.type = "text/javascript";\n  var scpt = document.getElementsByTagName(\'script\')[0];\n  scpt.parentNode.insertBefore(elem, scpt);\n  })();\n</script>\n<script type=\'text/javascript\'>window.ua={mobile:0};</script>\n<link rel="preload" as="font" href="http://pics3.city-data.com/fonts/glyphicons-halflings-regular.woff2" type="font/woff2" crossorigin="anonymous"/>\n<link rel="preload" as="script" href="http://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js" crossorigin="anonymous"/>\n<link rel="preload" as="script" href="http://maxcdn.bootstrapcdn.com/bootstrap/3.3.2/js/bootstrap.min.js" crossorigin="anonymous"/>\n\n\n<style>\n#sticky-ad {height:800px;max-width:300px;}\n#left-ad {height:800px;max-width:300px;}\n#anchor-ad {display:none;}\n.horizontal-ad {min-height:90px;max-width:1200px;margin:5px auto;overflow:hidden;}\n\n</style>\n\n\n<link href="http://maxcdn.bootstrapcdn.com/bootstrap/3.3.2/css/bootstrap.min.css" rel="stylesheet">\n\n\n<style>\nbody {font-size: 16px;}\nhr {margin-top: 22px;margin-bottom: 22px;}\nh1,.h1,h2,.h2,h3,.h3 {margin-top: 22px;margin-bottom: 11px;}\nh4,.h4,h5,.h5,h6,.h6 {margin-top: 11px;margin-bottom: 11px;}\nh1,.h1 {  font-size: 41px;}\nh2,.h2 {  font-size: 34px;}\nh3,.h3 {  font-size: 28px;}\nh4,.h4 {  font-size: 20px;}\nh5,.h5 {  font-size: 16px;}\nh6,.h6 {  font-size: 14px;}\np {  margin: 0 0 11px;}\n.lead {  margin-bottom: 22px;  font-size: 18px;}\n\n@media (min-width: 768px) {  .lead {font-size: 24px;}}\nsmall,.small {font-size: 87%;}\n.page-header {  padding-bottom: 10px;  margin: 44px 0 22px;}\n\nul,ol {  margin-bottom: 11px;}\ndl {  margin-bottom: 22px;}\n\nblockquote {  padding: 11px 22px;  margin: 0 0 22px;  font-size: 20px;}\naddress {  margin-bottom: 22px;}\n.table {margin-bottom: 22px;}\n@media screen and (max-width: 767px) {  .table-responsive { margin-bottom: 16.5px;} }\n\n.dropdown-menu {font-size: 16px;}\n.dropdown-menu .divider {margin: 10px 0;}\n.dropdown-header {font-size: 14px;}\n\n.nav .nav-divider {margin: 10px 0;}\n.navbar {margin-bottom: 22px;}\n.navbar-brand {padding: 14px 15px;font-size: 20px;line-height: 22px;}\n\n.navbar-nav > li > a {  line-height: 22px;}\n@media (max-width: 767px) {.navbar-nav .open .dropdown-menu > li > a {line-height: 22px;}}\n@media (min-width: 768px) {.navbar-nav > li > a {padding-top: 14px;padding-bottom: 14px;}}\n.navbar-btn {  margin-top: 7px;  margin-bottom: 7px;}\n.navbar-btn.btn-sm {  margin-top: 8.5px;  margin-bottom: 8.5px;}\n.navbar-text {  margin-top: 14px;  margin-bottom: 14px;}\n\n.breadcrumb { margin-bottom: 22px;}\n.pagination { margin: 22px 0;}\n.pagination-lg > li > a,.pagination-lg > li > span { font-size: 20px;}\n.pagination-sm > li > a,.pagination-sm > li > span {  font-size: 14px;}\n.thumbnail {  margin-bottom: 22px;}\n.alert {  margin-bottom: 22px;}\n\n\n.gBorder, .gBorder div {max-width: 100%;}\n.barG, .barG div, .pieG, .pieG div, .lineG, .lineG div {max-width: 100%}\n.gBorder img, section img {max-width:100%;height:auto;}\n#body { padding: 0px }\n@media(max-width: 400px) {\n\tbody > div.container-fluid {\n\tpadding-left: 5px;\n\tpadding-right: 5px;\n\t}\n}\n@media(min-width: 768px) {\n\tbody > div.container-fluid {\n\ ...
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-36-f754f31016ef> in <module>()
#      15 #       'http://www.city-data.com/indexes/neighborhoods/IA/13']
#      16
# ---> 17 p = requests.get(url)
#      18 b = BeautifulSoup(p.content, "html.parser")
#      19
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     610
#     611         # Get the appropriate adapter to use
# --> 612         adapter = self.get_adapter(url=request.url)
#     613
#     614         # Start time (approximately) of the request
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/sessions.py in get_adapter(self, url)
#     701
#     702         # Nothing matches :-/
# --> 703         raise InvalidSchema("No connection adapters were found for '%s'" % url)
#     704
#     705     def close(self):
#
# InvalidSchema: No connection adapters were found for '['http://www.city-data.com/indexes/neighborhoods/IA/1', 'http://www.city-data.com/indexes/neighborhoods/IA/2', 'http://www.city-data.com/indexes/neighborhoods/IA/3', 'http://www.city-data.com/indexes/neighborhoods/IA/4', 'http://www.city-data.com/indexes/neighborhoods/IA/5', 'http://www.city-data.com/indexes/neighborhoods/IA/6', 'http://www.city-data.com/indexes/neighborhoods/IA/7', 'http://www.city-data.com/indexes/neighborhoods/IA/8', 'http://www.city-data.com/indexes/neighborhoods/IA/9', 'http://www.city-data.com/indexes/neighborhoods/IA/10', 'http://www.city-data.com/indexes/neighborhoods/IA/11,http://www.city-data.com/indexes/neighborhoods/IA/12', 'http://www.city-data.com/indexes/neighborhoods/IA/13']'

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/2'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : "neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-37-2eb4101ca62b> in <module>()
#       1 url = 'http://www.city-data.com/indexes/neighborhoods/IA/2'
#       2
# ----> 3 html = urlopen(url)
#       4 bs = BeautifulSoup(html, "lxml")
#       5
#
# /opt/anaconda3/envs/jh/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /opt/anaconda3/envs/jh/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     470         for processor in self.process_response.get(protocol, []):
#     471             meth = getattr(processor, meth_name)
# --> 472             response = meth(req, response)
#     473
#     474         return response
#
# /opt/anaconda3/envs/jh/lib/python3.5/urllib/request.py in http_response(self, request, response)
#     580         if not (200 <= code < 300):
#     581             response = self.parent.error(
# --> 582                 'http', request, response, code, msg, hdrs)
#     583
#     584         return response
#
# /opt/anaconda3/envs/jh/lib/python3.5/urllib/request.py in error(self, proto, *args)
#     508         if http_err:
#     509             args = (dict, 'default', 'http_error_default') + orig_args
# --> 510             return self._call_chain(*args)
#     511
#     512 # XXX probably also want an abstract factory that knows when it makes
#
# /opt/anaconda3/envs/jh/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /opt/anaconda3/envs/jh/lib/python3.5/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     588 class HTTPDefaultErrorHandler(BaseHandler):
#     589     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 590         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     591
#     592 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/3'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : "neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/4'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : "neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/5'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : "neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/6'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : "neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/7'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : from urllib import urlopen
"neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/8'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : from urllib import urlopen
"neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/9'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : from urllib import urlopen
"neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/10'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : from urllib import urlopen
"neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/11'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : from urllib import urlopen
"neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/12'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : from urllib import urlopen
"neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/IA/13'

html = urlopen(url)
bs = BeautifulSoup(html, "lxml")

links = bs.find("div", {"id" : from urllib import urlopen
"neighborhood_index"}).findAll("a" , href=re.compile("(/neighborhood/)+([A-Za-z0-9_:()])+(Des-Moines)+"))

for link in links:
    print(link['title'], link['href'])
