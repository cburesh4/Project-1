# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/home/burecod/notebooks/project1'

# %%
df = pd.read_csv(r'/home/burecod/notebooks/project1/raleigh_neighborhoods.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Area: Population: avg household size  \
# 0           0           0.0  0.019           4        21.0 people
# 1           1           1.0  0.089          12         2.2 people
# 2           2           2.0  0.025          55         2.1 people
# 3           3           3.0  0.005          29         2.4 people
# 4           4           4.0  0.091          55         2.3 people
#
#   avg number of cars apts avg number of cars houses males med age females  \
# 0                     1.7                       1.7     2      36.7 years
# 1                  88.60%                       1.9     6      37.9 years
# 2                     1.2                       2.2    28      59.9 years
# 3                     1.7                       1.7    10      24.0 years
# 4                     1.7                       1.8    26      40.8 years
#
#   med age males        ...         pct families with children  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1       Area:
# count  669.000000    668.000000  662.000000
# mean   334.000000    333.500000    0.085204
# std    193.267949    192.979273    0.346321
# min      0.000000      0.000000    0.001000
# 25%    167.000000    166.750000    0.009000
# 50%    334.000000    333.500000    0.027000
# 75%    501.000000    500.250000    0.071750
# max    668.000000    667.000000    7.865000

# %%
df.rename(columns = {'Area:' : 'area',
                     'Population:' : 'population',
                     'avg household size' : 'avg_household_size',
                     'avg number of cars apts' : 'avg_car_amount_apt',
                     'avg number of cars houses' : 'avg_car_amount_house',
                     'med age females' : 'female_median_age',
                     'med age males' : 'male_median_age',
                     'pct families with children' : 'families_with_children_pct',
                     'pct family household' : 'family_household_pct',
                     'pct foreign born residents' : 'foreign_born_pct',
                     'pct married couple':'married_pct',
                     'pct native residents born outside us' : 'natives_born_outside_us_pct',
                     'pct never married females > 15':'single_females_pct',
                     'pct never married males > 15':'single_males_pct',
                     'pct not speak English well':'ESL_pct',
                     'pct single mother':'single_mother_pct',
                     'pct units mortgage' : 'mortgage_units_pct'}, inplace = True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   area population avg_household_size  \
# 0           0           0.0  0.019          4        21.0 people
# 1           1           1.0  0.089         12         2.2 people
# 2           2           2.0  0.025         55         2.1 people
# 3           3           3.0  0.005         29         2.4 people
# 4           4           4.0  0.091         55         2.3 people
#
#   avg_car_amount_apt avg_car_amount_house males female_median_age  \
# 0                1.7                  1.7     2        36.7 years
# 1             88.60%                  1.9     6        37.9 years
# 2                1.2                  2.2    28        59.9 years
# 3                1.7                  1.7    10        24.0 years
# 4                1.7                  1.8    26        40.8 years
#
#   male_median_age        ...         families_with_children_pct  \
# 0      30.7 years        ...                             48.30%
# ...

# %%
df.area = df.area.astype(str).str.extract('([\d.]+)', expand = True)
df.population = df.population.str.extract('([\d.]+)', expand = True)
df.avg_household_size = df.avg_household_size.str.extract('([\d.]+)', expand = True)
df.avg_car_amount_apt = df.avg_car_amount_apt.str.extract('([\d.]+)', expand = True)
df.avg_car_amount_house = df.avg_car_amount_house.str.extract('([\d.]+)', expand = True)
df.male_median_age = df.male_median_age.str.extract('([\d.]+)', expand = True)
df.female_median_age = df.female_median_age.str.extract('([\d.]+)', expand = True)
df.males = df.males.str.replace(',','')
df.families_with_children_pct = df.families_with_children_pct.str.extract('([\d.]+)', expand = True)
df.family_household_pct = df.family_household_pct.str.extract('([\d.]+)', expand = True)
df.foreign_born_pct = df.foreign_born_pct.str.extract('([\d.]+)', expand = True)
df.married_pct = df.married_pct.str.extract('([\d.]+)', expand = True)
df.natives_born_outside_us_pct = df.natives_born_outside_us_pct.str.extract('([\d.]+)', expand = True)
df.single_females_pct = df.single_females_pct.str.extract('([\d.]+)', expand = True)
df.single_males_pct = df.single_males_pct.str.extract('([\d.]+)', expand = True)
df.ESL_pct = df.ESL_pct.str.extract('([\d.]+)', expand = True)
df.single_mother_pct = df.single_mother_pct.str.extract('([\d.]+)', expand = True)
df.mortgage_units_pct = df.mortgage_units_pct.str.extract('([\d.]+)', expand = True)

# %%
df['neighborhood']
# Out:
# 0                           Alanda,Raleigh, NC
# 1        Alexander Place Townhomes,Raleigh, NC
# 2                Alexandria Square,Raleigh, NC
# 3                            Alpha,Raleigh, NC
# 4                       Amberfield,Raleigh, NC
# 5                        Ammondale,Raleigh, NC
# 6                  Anderson Forest,Raleigh, NC
# 7                 Anderson Heights,Raleigh, NC
# 8                  Appollo Heights,Raleigh, NC
# 9                      Arbor Chase,Raleigh, NC
# 10                     Arbor Ridge,Raleigh, NC
# 11       Arbor at Harrington Grove,Raleigh, NC
# 12                    Arden Forest,Raleigh, NC
# 13                 Arlington Hills,Raleigh, NC
# 14                 Arlington Place,Raleigh, NC
# 15                     Arrowspring,Raleigh, NC
# 16                       Ashebrook,Raleigh, NC
# 17                       Ashebrook,Raleigh, NC
# 18                   Ashland Place,Raleigh, NC
# 19                     Ashley Park,Raleigh, NC
# ...

# %%
from geopy.geocoders import Nominatim
def get_neigh_coords(inputAddress):
    try:
        geolocator = Nominatim(user_agent = 'my-application')
        location = geolocator.geocode(inputAddress)
        time.sleep(2)
        print('.')
        return location.latitude,location.longitude
    except:
        return None,None

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   area population avg_household_size  \
# 0           0           0.0  0.019          4               21.0
# 1           1           1.0  0.089         12                2.2
# 2           2           2.0  0.025         55                2.1
# 3           3           3.0  0.005         29                2.4
# 4           4           4.0  0.091         55                2.3
#
#   avg_car_amount_apt avg_car_amount_house males female_median_age  \
# 0                1.7                  1.7     2              36.7
# 1              88.60                  1.9     6              37.9
# 2                1.2                  2.2    28              59.9
# 3                1.7                  1.7    10              24.0
# 4                1.7                  1.8    26              40.8
#
#   male_median_age        ...         families_with_children_pct  \
# 0            30.7        ...                              48.30
# ...

# %%
df['coords'] = df.apply(lambda x:get_neigh_coords(x))

# %%
df['lat'] = df.apply(lambda x:x[0])
df['lon'] = df.apply(lambda x:x[1])

# %%
df.to_csv('DataCleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   area population avg_household_size  \
# 0           0           0.0  0.019          4               21.0
# 1           1           1.0  0.089         12                2.2
# 2           2           2.0  0.025         55                2.1
# 3           3           3.0  0.005         29                2.4
# 4           4           4.0  0.091         55                2.3
#
#   avg_car_amount_apt avg_car_amount_house males female_median_age  \
# 0                1.7                  1.7     2              36.7
# 1              88.60                  1.9     6              37.9
# 2                1.2                  2.2    28              59.9
# 3                1.7                  1.7    10              24.0
# 4                1.7                  1.8    26              40.8
#
#   male_median_age ...  married_pct natives_born_outside_us_pct  \
# 0            30.7 ...        30.30                        1.10
# ...
